# %%
import os

# %%
CUSTOM_MODEL_NAME = 'my_ssd_mobnet' 
PRETRAINED_MODEL_NAME = 'ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8'
PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8.tar.gz'
TF_RECORD_SCRIPT_NAME = 'generate_tfrecord.py'
LABEL_MAP_NAME = 'label_map.pbtxt'

# %%
paths = {
    'WORKSPACE_PATH': os.path.join('Tensorflow', 'workspace'),
    'SCRIPTS_PATH': os.path.join('Tensorflow','scripts'),
    'APIMODEL_PATH': os.path.join('Tensorflow','models'),
    'ANNOTATION_PATH': os.path.join('Tensorflow', 'workspace','annotations'),
    'IMAGE_PATH': os.path.join('Tensorflow', 'workspace','images'),
    'MODEL_PATH': os.path.join('Tensorflow', 'workspace','models'),
    'PRETRAINED_MODEL_PATH': os.path.join('Tensorflow', 'workspace','pre-trained-models'),
    'CHECKPOINT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME), 
    'OUTPUT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'export'), 
    'TFJS_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfjsexport'), 
    'TFLITE_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfliteexport'), 
    'PROTOC_PATH':os.path.join('Tensorflow','protoc')
 }

# %%
files = {
    'PIPELINE_CONFIG':os.path.join('Tensorflow', 'workspace','models', CUSTOM_MODEL_NAME, 'pipeline.config'),
    'TF_RECORD_SCRIPT': os.path.join(paths['SCRIPTS_PATH'], TF_RECORD_SCRIPT_NAME), 
    'LABELMAP': os.path.join(paths['ANNOTATION_PATH'], LABEL_MAP_NAME)
}

# %%
for path in paths.values():
    if not os.path.exists(path):
        if os.name == 'posix':
            # !mkdir -p {path}
        if os.name == 'nt':
            # !mkdir {path}

# %%
# Installation

# %%
if os.name=='nt':
    # !pip install wget
    import wget
# Out:
# Requirement already satisfied: wget in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (3.2)

# %%
if not os.path.exists(os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection')):
    # !git clone https://github.com/tensorflow/models {paths['APIMODEL_PATH']}

# %%
# Install Tensorflow Object Detection 
if os.name=='posix':  
    # !apt-get install protobuf-compiler
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py . && python -m pip install . 
    
if os.name=='nt':
    url="https://github.com/protocolbuffers/protobuf/releases/download/v3.15.6/protoc-3.15.6-win64.zip"
    wget.download(url)
    # !move protoc-3.15.6-win64.zip {paths['PROTOC_PATH']}
    # !cd {paths['PROTOC_PATH']} && tar -xf protoc-3.15.6-win64.zip
    os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))   
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build && python setup.py install
    # !cd Tensorflow/models/research/slim && pip install -e .
# Out:
# 100% [..........................................................................] 1468733 / 1468733
#         1 file(s) moved.
#         1 file(s) copied.
# running build
# running build_py
# copying object_detection\protos\anchor_generator_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\argmax_matcher_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\bipartite_matcher_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\box_coder_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\box_predictor_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\calibration_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\center_net_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\eval_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\faster_rcnn_box_coder_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\faster_rcnn_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\flexible_grid_anchor_generator_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\fpn_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\graph_rewriter_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\grid_anchor_generator_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\hyperparams_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\image_resizer_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\input_reader_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\keypoint_box_coder_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\losses_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\matcher_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\mean_stddev_box_coder_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\model_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\multiscale_anchor_generator_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\optimizer_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\pipeline_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\post_processing_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\preprocessor_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\region_similarity_calculator_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\square_box_coder_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\ssd_anchor_generator_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\ssd_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\string_int_label_map_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\target_assigner_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\train_pb2.py -> build\lib\object_detection\protos
# running egg_info
# writing manifest file 'object_detection.egg-info\SOURCES.txt'
# running install
# running bdist_egg
# running egg_info
# writing manifest file 'object_detection.egg-info\SOURCES.txt'
# running install_lib
# running build_py
# creating build\bdist.win-amd64\egg
# creating build\bdist.win-amd64\egg\datasets
# creating build\bdist.win-amd64\egg\deployment
# creating build\bdist.win-amd64\egg\nets
# creating build\bdist.win-amd64\egg\nets\mobilenet
# creating build\bdist.win-amd64\egg\nets\nasnet
# creating build\bdist.win-amd64\egg\object_detection
# creating build\bdist.win-amd64\egg\object_detection\anchor_generators
# creating build\bdist.win-amd64\egg\object_detection\box_coders
# creating build\bdist.win-amd64\egg\object_detection\builders
# creating build\bdist.win-amd64\egg\object_detection\core
# creating build\bdist.win-amd64\egg\object_detection\dataset_tools
# creating build\bdist.win-amd64\egg\object_detection\dataset_tools\context_rcnn
# creating build\bdist.win-amd64\egg\object_detection\data_decoders
# creating build\bdist.win-amd64\egg\object_detection\inference
# creating build\bdist.win-amd64\egg\object_detection\legacy
# creating build\bdist.win-amd64\egg\object_detection\matchers
# creating build\bdist.win-amd64\egg\object_detection\meta_architectures
# creating build\bdist.win-amd64\egg\object_detection\metrics
# creating build\bdist.win-amd64\egg\object_detection\models
# creating build\bdist.win-amd64\egg\object_detection\models\keras_models
# creating build\bdist.win-amd64\egg\object_detection\predictors
# creating build\bdist.win-amd64\egg\object_detection\predictors\heads
# creating build\bdist.win-amd64\egg\object_detection\protos
# creating build\bdist.win-amd64\egg\object_detection\tpu_exporters
# creating build\bdist.win-amd64\egg\object_detection\tpu_exporters\testdata
# creating build\bdist.win-amd64\egg\object_detection\utils
# creating build\bdist.win-amd64\egg\preprocessing
# byte-compiling build\bdist.win-amd64\egg\datasets\build_imagenet_data.py to build_imagenet_data.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\datasets\cifar10.py to cifar10.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\datasets\dataset_factory.py to dataset_factory.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\datasets\dataset_utils.py to dataset_utils.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\datasets\download_and_convert_cifar10.py to download_and_convert_cifar10.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\datasets\download_and_convert_flowers.py to download_and_convert_flowers.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\datasets\download_and_convert_mnist.py to download_and_convert_mnist.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\datasets\download_and_convert_visualwakewords.py to download_and_convert_visualwakewords.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\datasets\download_and_convert_visualwakewords_lib.py to download_and_convert_visualwakewords_lib.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\datasets\flowers.py to flowers.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\datasets\imagenet.py to imagenet.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\datasets\mnist.py to mnist.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\datasets\preprocess_imagenet_validation_data.py to preprocess_imagenet_validation_data.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\datasets\process_bounding_boxes.py to process_bounding_boxes.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\datasets\visualwakewords.py to visualwakewords.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\datasets\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\deployment\model_deploy.py to model_deploy.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\deployment\model_deploy_test.py to model_deploy_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\deployment\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\alexnet.py to alexnet.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\alexnet_test.py to alexnet_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\cifarnet.py to cifarnet.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\cyclegan.py to cyclegan.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\cyclegan_test.py to cyclegan_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\dcgan.py to dcgan.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\dcgan_test.py to dcgan_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\i3d.py to i3d.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\i3d_test.py to i3d_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\i3d_utils.py to i3d_utils.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\inception.py to inception.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\inception_resnet_v2.py to inception_resnet_v2.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\inception_resnet_v2_test.py to inception_resnet_v2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\inception_utils.py to inception_utils.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\inception_v1.py to inception_v1.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\inception_v1_test.py to inception_v1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\inception_v2.py to inception_v2.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\inception_v2_test.py to inception_v2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\inception_v3.py to inception_v3.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\inception_v3_test.py to inception_v3_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\inception_v4.py to inception_v4.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\inception_v4_test.py to inception_v4_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\lenet.py to lenet.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\mobilenet\conv_blocks.py to conv_blocks.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\mobilenet\mobilenet.py to mobilenet.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\mobilenet\mobilenet_v2.py to mobilenet_v2.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\mobilenet\mobilenet_v2_test.py to mobilenet_v2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\mobilenet\mobilenet_v3.py to mobilenet_v3.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\mobilenet\mobilenet_v3_test.py to mobilenet_v3_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\mobilenet\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\mobilenet_v1.py to mobilenet_v1.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\mobilenet_v1_eval.py to mobilenet_v1_eval.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\mobilenet_v1_test.py to mobilenet_v1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\mobilenet_v1_train.py to mobilenet_v1_train.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\nasnet\nasnet.py to nasnet.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\nasnet\nasnet_test.py to nasnet_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\nasnet\nasnet_utils.py to nasnet_utils.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\nasnet\nasnet_utils_test.py to nasnet_utils_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\nasnet\pnasnet.py to pnasnet.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\nasnet\pnasnet_test.py to pnasnet_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\nasnet\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\nets_factory.py to nets_factory.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\nets_factory_test.py to nets_factory_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\overfeat.py to overfeat.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\overfeat_test.py to overfeat_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\pix2pix.py to pix2pix.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\pix2pix_test.py to pix2pix_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\post_training_quantization.py to post_training_quantization.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\resnet_utils.py to resnet_utils.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\resnet_v1.py to resnet_v1.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\resnet_v1_test.py to resnet_v1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\resnet_v2.py to resnet_v2.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\resnet_v2_test.py to resnet_v2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\s3dg.py to s3dg.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\s3dg_test.py to s3dg_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\vgg.py to vgg.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\vgg_test.py to vgg_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\nets\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\anchor_generators\flexible_grid_anchor_generator.py to flexible_grid_anchor_generator.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\anchor_generators\flexible_grid_anchor_generator_test.py to flexible_grid_anchor_generator_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\anchor_generators\grid_anchor_generator.py to grid_anchor_generator.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\anchor_generators\grid_anchor_generator_test.py to grid_anchor_generator_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\anchor_generators\multiple_grid_anchor_generator.py to multiple_grid_anchor_generator.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\anchor_generators\multiple_grid_anchor_generator_test.py to multiple_grid_anchor_generator_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\anchor_generators\multiscale_grid_anchor_generator.py to multiscale_grid_anchor_generator.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\anchor_generators\multiscale_grid_anchor_generator_test.py to multiscale_grid_anchor_generator_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\anchor_generators\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\box_coders\faster_rcnn_box_coder.py to faster_rcnn_box_coder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\box_coders\faster_rcnn_box_coder_test.py to faster_rcnn_box_coder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\box_coders\keypoint_box_coder.py to keypoint_box_coder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\box_coders\keypoint_box_coder_test.py to keypoint_box_coder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\box_coders\mean_stddev_box_coder.py to mean_stddev_box_coder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\box_coders\mean_stddev_box_coder_test.py to mean_stddev_box_coder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\box_coders\square_box_coder.py to square_box_coder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\box_coders\square_box_coder_test.py to square_box_coder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\box_coders\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\anchor_generator_builder.py to anchor_generator_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\anchor_generator_builder_test.py to anchor_generator_builder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\box_coder_builder.py to box_coder_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\box_coder_builder_test.py to box_coder_builder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\box_predictor_builder.py to box_predictor_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\box_predictor_builder_test.py to box_predictor_builder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\calibration_builder.py to calibration_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\calibration_builder_test.py to calibration_builder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\dataset_builder.py to dataset_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\dataset_builder_test.py to dataset_builder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\decoder_builder.py to decoder_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\decoder_builder_test.py to decoder_builder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\graph_rewriter_builder.py to graph_rewriter_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\graph_rewriter_builder_tf1_test.py to graph_rewriter_builder_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\hyperparams_builder.py to hyperparams_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\hyperparams_builder_test.py to hyperparams_builder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\image_resizer_builder.py to image_resizer_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\image_resizer_builder_test.py to image_resizer_builder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\input_reader_builder.py to input_reader_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\input_reader_builder_tf1_test.py to input_reader_builder_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\losses_builder.py to losses_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\losses_builder_test.py to losses_builder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\matcher_builder.py to matcher_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\matcher_builder_test.py to matcher_builder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\model_builder.py to model_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\model_builder_test.py to model_builder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\model_builder_tf1_test.py to model_builder_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\model_builder_tf2_test.py to model_builder_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\optimizer_builder.py to optimizer_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\optimizer_builder_tf1_test.py to optimizer_builder_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\optimizer_builder_tf2_test.py to optimizer_builder_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\post_processing_builder.py to post_processing_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\post_processing_builder_test.py to post_processing_builder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\preprocessor_builder.py to preprocessor_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\preprocessor_builder_test.py to preprocessor_builder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\region_similarity_calculator_builder.py to region_similarity_calculator_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\region_similarity_calculator_builder_test.py to region_similarity_calculator_builder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\target_assigner_builder.py to target_assigner_builder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\target_assigner_builder_test.py to target_assigner_builder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\builders\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\anchor_generator.py to anchor_generator.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\balanced_positive_negative_sampler.py to balanced_positive_negative_sampler.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\balanced_positive_negative_sampler_test.py to balanced_positive_negative_sampler_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\batcher.py to batcher.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\batcher_tf1_test.py to batcher_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\batch_multiclass_nms_test.py to batch_multiclass_nms_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\box_coder.py to box_coder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\box_coder_test.py to box_coder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\box_list.py to box_list.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\box_list_ops.py to box_list_ops.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\box_list_ops_test.py to box_list_ops_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\box_list_test.py to box_list_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\box_predictor.py to box_predictor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\class_agnostic_nms_test.py to class_agnostic_nms_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\data_decoder.py to data_decoder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\data_parser.py to data_parser.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\densepose_ops.py to densepose_ops.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\densepose_ops_test.py to densepose_ops_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\freezable_batch_norm.py to freezable_batch_norm.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\freezable_batch_norm_tf2_test.py to freezable_batch_norm_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\freezable_sync_batch_norm.py to freezable_sync_batch_norm.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\keypoint_ops.py to keypoint_ops.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\keypoint_ops_test.py to keypoint_ops_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\losses.py to losses.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\losses_test.py to losses_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\matcher.py to matcher.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\matcher_test.py to matcher_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\minibatch_sampler.py to minibatch_sampler.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\minibatch_sampler_test.py to minibatch_sampler_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\model.py to model.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\model_test.py to model_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\multiclass_nms_test.py to multiclass_nms_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\post_processing.py to post_processing.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\prefetcher.py to prefetcher.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\prefetcher_tf1_test.py to prefetcher_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\preprocessor.py to preprocessor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\preprocessor_cache.py to preprocessor_cache.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\preprocessor_test.py to preprocessor_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\region_similarity_calculator.py to region_similarity_calculator.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\region_similarity_calculator_test.py to region_similarity_calculator_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\standard_fields.py to standard_fields.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\target_assigner.py to target_assigner.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\target_assigner_test.py to target_assigner_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\core\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\context_rcnn\add_context_to_examples.py to add_context_to_examples.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\context_rcnn\add_context_to_examples_tf2_test.py to add_context_to_examples_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\context_rcnn\create_cococameratraps_tfexample_main.py to create_cococameratraps_tfexample_main.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\context_rcnn\create_cococameratraps_tfexample_tf2_test.py to create_cococameratraps_tfexample_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\context_rcnn\generate_detection_data.py to generate_detection_data.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\context_rcnn\generate_detection_data_tf2_test.py to generate_detection_data_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\context_rcnn\generate_embedding_data.py to generate_embedding_data.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\context_rcnn\generate_embedding_data_tf2_test.py to generate_embedding_data_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\context_rcnn\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\create_ava_actions_tf_record.py to create_ava_actions_tf_record.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\create_coco_tf_record.py to create_coco_tf_record.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\create_coco_tf_record_test.py to create_coco_tf_record_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\create_kitti_tf_record.py to create_kitti_tf_record.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\create_kitti_tf_record_test.py to create_kitti_tf_record_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\create_oid_tf_record.py to create_oid_tf_record.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\create_pascal_tf_record.py to create_pascal_tf_record.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\create_pascal_tf_record_test.py to create_pascal_tf_record_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\create_pet_tf_record.py to create_pet_tf_record.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\oid_hierarchical_labels_expansion.py to oid_hierarchical_labels_expansion.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\oid_hierarchical_labels_expansion_test.py to oid_hierarchical_labels_expansion_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\oid_tfrecord_creation.py to oid_tfrecord_creation.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\oid_tfrecord_creation_test.py to oid_tfrecord_creation_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\seq_example_util.py to seq_example_util.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\seq_example_util_test.py to seq_example_util_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\tf_record_creation_util.py to tf_record_creation_util.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\tf_record_creation_util_test.py to tf_record_creation_util_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\dataset_tools\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\data_decoders\tf_example_decoder.py to tf_example_decoder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\data_decoders\tf_example_decoder_test.py to tf_example_decoder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\data_decoders\tf_sequence_example_decoder.py to tf_sequence_example_decoder.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\data_decoders\tf_sequence_example_decoder_test.py to tf_sequence_example_decoder_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\data_decoders\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\eval_util.py to eval_util.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\eval_util_test.py to eval_util_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\exporter.py to exporter.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\exporter_lib_tf2_test.py to exporter_lib_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\exporter_lib_v2.py to exporter_lib_v2.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\exporter_main_v2.py to exporter_main_v2.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\exporter_tf1_test.py to exporter_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\export_inference_graph.py to export_inference_graph.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\export_tflite_graph_lib_tf2.py to export_tflite_graph_lib_tf2.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\export_tflite_graph_lib_tf2_test.py to export_tflite_graph_lib_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\export_tflite_graph_tf2.py to export_tflite_graph_tf2.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\export_tflite_ssd_graph.py to export_tflite_ssd_graph.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\export_tflite_ssd_graph_lib.py to export_tflite_ssd_graph_lib.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\export_tflite_ssd_graph_lib_tf1_test.py to export_tflite_ssd_graph_lib_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\inference\detection_inference.py to detection_inference.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\inference\detection_inference_tf1_test.py to detection_inference_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\inference\infer_detections.py to infer_detections.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\inference\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\inputs.py to inputs.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\inputs_test.py to inputs_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\legacy\eval.py to eval.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\legacy\evaluator.py to evaluator.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\legacy\train.py to train.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\legacy\trainer.py to trainer.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\legacy\trainer_tf1_test.py to trainer_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\legacy\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\matchers\argmax_matcher.py to argmax_matcher.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\matchers\argmax_matcher_test.py to argmax_matcher_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\matchers\bipartite_matcher.py to bipartite_matcher.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\matchers\bipartite_matcher_tf1_test.py to bipartite_matcher_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\matchers\hungarian_matcher.py to hungarian_matcher.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\matchers\hungarian_matcher_tf2_test.py to hungarian_matcher_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\matchers\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\center_net_meta_arch.py to center_net_meta_arch.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\center_net_meta_arch_tf2_test.py to center_net_meta_arch_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\context_rcnn_lib.py to context_rcnn_lib.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\context_rcnn_lib_tf1_test.py to context_rcnn_lib_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\context_rcnn_lib_tf2.py to context_rcnn_lib_tf2.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\context_rcnn_lib_tf2_test.py to context_rcnn_lib_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\context_rcnn_meta_arch.py to context_rcnn_meta_arch.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\context_rcnn_meta_arch_test.py to context_rcnn_meta_arch_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\deepmac_meta_arch.py to deepmac_meta_arch.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\deepmac_meta_arch_test.py to deepmac_meta_arch_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\faster_rcnn_meta_arch.py to faster_rcnn_meta_arch.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\faster_rcnn_meta_arch_test.py to faster_rcnn_meta_arch_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\faster_rcnn_meta_arch_test_lib.py to faster_rcnn_meta_arch_test_lib.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\rfcn_meta_arch.py to rfcn_meta_arch.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\rfcn_meta_arch_test.py to rfcn_meta_arch_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\ssd_meta_arch.py to ssd_meta_arch.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\ssd_meta_arch_test.py to ssd_meta_arch_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\ssd_meta_arch_test_lib.py to ssd_meta_arch_test_lib.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\meta_architectures\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\calibration_evaluation.py to calibration_evaluation.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\calibration_evaluation_tf1_test.py to calibration_evaluation_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\calibration_metrics.py to calibration_metrics.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\calibration_metrics_tf1_test.py to calibration_metrics_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\coco_evaluation.py to coco_evaluation.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\coco_evaluation_test.py to coco_evaluation_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\coco_tools.py to coco_tools.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\coco_tools_test.py to coco_tools_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\io_utils.py to io_utils.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\lvis_evaluation.py to lvis_evaluation.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\lvis_evaluation_test.py to lvis_evaluation_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\lvis_tools.py to lvis_tools.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\lvis_tools_test.py to lvis_tools_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\offline_eval_map_corloc.py to offline_eval_map_corloc.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\offline_eval_map_corloc_test.py to offline_eval_map_corloc_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\oid_challenge_evaluation.py to oid_challenge_evaluation.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\oid_challenge_evaluation_utils.py to oid_challenge_evaluation_utils.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\oid_challenge_evaluation_utils_test.py to oid_challenge_evaluation_utils_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\oid_vrd_challenge_evaluation.py to oid_vrd_challenge_evaluation.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\oid_vrd_challenge_evaluation_utils.py to oid_vrd_challenge_evaluation_utils.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\oid_vrd_challenge_evaluation_utils_test.py to oid_vrd_challenge_evaluation_utils_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\tf_example_parser.py to tf_example_parser.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\tf_example_parser_test.py to tf_example_parser_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\metrics\__init__.py to __init__.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\bidirectional_feature_pyramid_generators.py to bidirectional_feature_pyramid_generators.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\bidirectional_feature_pyramid_generators_tf2_test.py to bidirectional_feature_pyramid_generators_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\center_net_hourglass_feature_extractor.py to center_net_hourglass_feature_extractor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\center_net_hourglass_feature_extractor_tf2_test.py to center_net_hourglass_feature_extractor_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\center_net_mobilenet_v2_feature_extractor.py to center_net_mobilenet_v2_feature_extractor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\center_net_mobilenet_v2_feature_extractor_tf2_test.py to center_net_mobilenet_v2_feature_extractor_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\center_net_mobilenet_v2_fpn_feature_extractor.py to center_net_mobilenet_v2_fpn_feature_extractor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\center_net_mobilenet_v2_fpn_feature_extractor_tf2_test.py to center_net_mobilenet_v2_fpn_feature_extractor_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\center_net_resnet_feature_extractor.py to center_net_resnet_feature_extractor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\center_net_resnet_feature_extractor_tf2_test.py to center_net_resnet_feature_extractor_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\center_net_resnet_v1_fpn_feature_extractor.py to center_net_resnet_v1_fpn_feature_extractor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\center_net_resnet_v1_fpn_feature_extractor_tf2_test.py to center_net_resnet_v1_fpn_feature_extractor_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\embedded_ssd_mobilenet_v1_feature_extractor.py to embedded_ssd_mobilenet_v1_feature_extractor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\embedded_ssd_mobilenet_v1_feature_extractor_tf1_test.py to embedded_ssd_mobilenet_v1_feature_extractor_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_inception_resnet_v2_feature_extractor.py to faster_rcnn_inception_resnet_v2_feature_extractor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_inception_resnet_v2_feature_extractor_tf1_test.py to faster_rcnn_inception_resnet_v2_feature_extractor_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_inception_resnet_v2_keras_feature_extractor.py to faster_rcnn_inception_resnet_v2_keras_feature_extractor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_inception_resnet_v2_keras_feature_extractor_tf2_test.py to faster_rcnn_inception_resnet_v2_keras_feature_extractor_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_inception_v2_feature_extractor.py to faster_rcnn_inception_v2_feature_extractor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_inception_v2_feature_extractor_tf1_test.py to faster_rcnn_inception_v2_feature_extractor_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_mobilenet_v1_feature_extractor.py to faster_rcnn_mobilenet_v1_feature_extractor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_mobilenet_v1_feature_extractor_tf1_test.py to faster_rcnn_mobilenet_v1_feature_extractor_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_nas_feature_extractor.py to faster_rcnn_nas_feature_extractor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_nas_feature_extractor_tf1_test.py to faster_rcnn_nas_feature_extractor_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_pnas_feature_extractor.py to faster_rcnn_pnas_feature_extractor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_pnas_feature_extractor_tf1_test.py to faster_rcnn_pnas_feature_extractor_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_resnet_keras_feature_extractor.py to faster_rcnn_resnet_keras_feature_extractor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_resnet_keras_feature_extractor_tf2_test.py to faster_rcnn_resnet_keras_feature_extractor_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_resnet_v1_feature_extractor.py to faster_rcnn_resnet_v1_feature_extractor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_resnet_v1_feature_extractor_tf1_test.py to faster_rcnn_resnet_v1_feature_extractor_tf1_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_resnet_v1_fpn_keras_feature_extractor.py to faster_rcnn_resnet_v1_fpn_keras_feature_extractor.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\faster_rcnn_resnet_v1_fpn_keras_feature_extractor_tf2_test.py to faster_rcnn_resnet_v1_fpn_keras_feature_extractor_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\feature_map_generators.py to feature_map_generators.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\feature_map_generators_test.py to feature_map_generators_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\keras_models\convert_keras_models.py to convert_keras_models.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\keras_models\hourglass_network.py to hourglass_network.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\keras_models\hourglass_network_tf2_test.py to hourglass_network_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\keras_models\inception_resnet_v2.py to inception_resnet_v2.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\keras_models\inception_resnet_v2_tf2_test.py to inception_resnet_v2_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\keras_models\mobilenet_v1.py to mobilenet_v1.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\keras_models\mobilenet_v1_tf2_test.py to mobilenet_v1_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\keras_models\mobilenet_v2.py to mobilenet_v2.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\keras_models\mobilenet_v2_tf2_test.py to mobilenet_v2_tf2_test.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\keras_models\model_utils.py to model_utils.cpython-39.pyc
# byte-compiling build\bdist.win-amd64\egg\object_detection\models\keras_models\nonlocal_block.py to nonlocal_block.cpython-39.pyc
# ...
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\tpu_exporters\utils.py to utils.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\tpu_exporters\utils_test.py to utils_test.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\tpu_exporters\testdata\__init__.py to __init__.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\__init__.py to __init__.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\autoaugment_utils.py to autoaugment_utils.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\bifpn_utils.py to bifpn_utils.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\category_util.py to category_util.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\category_util_test.py to category_util_test.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\colab_utils.py to colab_utils.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\config_util.py to config_util.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\config_util_test.py to config_util_test.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\context_manager.py to context_manager.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\context_manager_test.py to context_manager_test.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\dataset_util.py to dataset_util.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\dataset_util_test.py to dataset_util_test.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\json_utils.py to json_utils.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\json_utils_test.py to json_utils_test.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\label_map_util.py to label_map_util.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\label_map_util_test.py to label_map_util_test.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\learning_schedules.py to learning_schedules.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\learning_schedules_test.py to learning_schedules_test.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\metrics.py to metrics.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\metrics_test.py to metrics_test.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\model_util.py to model_util.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\model_util_tf2_test.py to model_util_tf2_test.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\np_box_list.py to np_box_list.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\np_box_list_ops.py to np_box_list_ops.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\np_box_list_ops_test.py to np_box_list_ops_test.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\np_box_list_test.py to np_box_list_test.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\np_box_mask_list.py to np_box_mask_list.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\np_box_mask_list_ops.py to np_box_mask_list_ops.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\np_box_mask_list_ops_test.py to np_box_mask_list_ops_test.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\np_box_mask_list_test.py to np_box_mask_list_test.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\np_box_ops.py to np_box_ops.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\np_box_ops_test.py to np_box_ops_test.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\np_mask_ops.py to np_mask_ops.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\np_mask_ops_test.py to np_mask_ops_test.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\object_detection_evaluation.py to object_detection_evaluation.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\object_detection_evaluation_test.py to object_detection_evaluation_test.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\ops.py to ops.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\ops_test.py to ops_test.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\patch_ops.py to patch_ops.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\patch_ops_test.py to patch_ops_test.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\per_image_evaluation.py to per_image_evaluation.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\per_image_evaluation_test.py to per_image_evaluation_test.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\per_image_vrd_evaluation.py to per_image_vrd_evaluation.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\per_image_vrd_evaluation_test.py to per_image_vrd_evaluation_test.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\shape_utils.py to shape_utils.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\shape_utils_test.py to shape_utils_test.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\spatial_transform_ops.py to spatial_transform_ops.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\spatial_transform_ops_test.py to spatial_transform_ops_test.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\static_shape.py to static_shape.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\static_shape_test.py to static_shape_test.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\target_assigner_utils.py to target_assigner_utils.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\target_assigner_utils_test.py to target_assigner_utils_test.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\test_case.py to test_case.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\test_case_test.py to test_case_test.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\test_utils.py to test_utils.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\test_utils_test.py to test_utils_test.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\tf_version.py to tf_version.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\variables_helper.py to variables_helper.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\variables_helper_tf1_test.py to variables_helper_tf1_test.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\visualization_utils.py to visualization_utils.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\visualization_utils_test.py to visualization_utils_test.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\vrd_evaluation.py to vrd_evaluation.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\utils\vrd_evaluation_test.py to vrd_evaluation_test.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\preprocessing\__init__.py to __init__.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\preprocessing\cifarnet_preprocessing.py to cifarnet_preprocessing.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\preprocessing\inception_preprocessing.py to inception_preprocessing.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\preprocessing\lenet_preprocessing.py to lenet_preprocessing.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\preprocessing\preprocessing_factory.py to preprocessing_factory.cpython-39.pyc
# byte-compiling c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg\preprocessing\vgg_preprocessing.py to vgg_preprocessing.cpython-39.pyc
# object-detection 0.1 is already the active version in easy-install.pth
#
# Installed c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages\object_detection-0.1-py3.9.egg
# Processing dependencies for object-detection==0.1
# C:\Users\Lucas2k16\Desktop\Uni\GKI\Coffeelist\venv\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# C:\Users\Lucas2k16\Desktop\Uni\GKI\Coffeelist\venv\lib\site-packages\setuptools\command\easy_install.py:156: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# zip_safe flag not set; analyzing archive contents...
# object_detection.core.__pycache__.densepose_ops.cpython-39: module references __file__
# object_detection.core.__pycache__.preprocessor.cpython-39: module MAY be using inspect.stack
# object_detection.utils.__pycache__.autoaugment_utils.cpython-39: module MAY be using inspect.stack
# error: numpy 1.23.1 is installed but numpy<1.23.0,>=1.14.3 is required by {'apache-beam'}
# Obtaining file:///C:/Users/Lucas2k16/Desktop/Uni/GKI/Coffeelist/Tensorflow/models/research/slim
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: six in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from slim==0.1) (1.16.0)
# Requirement already satisfied: tf-slim>=1.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from slim==0.1) (1.1.0)
# Requirement already satisfied: absl-py>=0.2.2 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tf-slim>=1.1->slim==0.1) (1.2.0)
# Installing collected packages: slim
#   Attempting uninstall: slim
#     Found existing installation: slim 0.1
#     Uninstalling slim-0.1:
#       Successfully uninstalled slim-0.1
#   Running setup.py develop for slim
# Successfully installed slim-0.1

# %%
VERIFICATION_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'builders', 'model_builder_tf2_test.py')
# Verify Installation
# !python {VERIFICATION_SCRIPT}
# Out:
# 2022-08-14 16:12:06.310436: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2022-08-14 16:12:06.310503: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-08-14 16:12:11.380721: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2022-08-14 16:12:11.380921: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cublas64_11.dll'; dlerror: cublas64_11.dll not found
# 2022-08-14 16:12:11.381100: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cublasLt64_11.dll'; dlerror: cublasLt64_11.dll not found
# 2022-08-14 16:12:11.381280: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cufft64_10.dll'; dlerror: cufft64_10.dll not found
# 2022-08-14 16:12:11.381454: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'curand64_10.dll'; dlerror: curand64_10.dll not found
# 2022-08-14 16:12:11.381621: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cusolver64_11.dll'; dlerror: cusolver64_11.dll not found
# 2022-08-14 16:12:11.381796: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cusparse64_11.dll'; dlerror: cusparse64_11.dll not found
# 2022-08-14 16:12:11.381967: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudnn64_8.dll'; dlerror: cudnn64_8.dll not found
# 2022-08-14 16:12:11.381988: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Running tests under Python 3.9.13: C:\Users\Lucas2k16\Desktop\Uni\GKI\Coffeelist\venv\Scripts\python.exe
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2022-08-14 16:12:11.389173: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# C:\Users\Lucas2k16\Desktop\Uni\GKI\Coffeelist\venv\lib\site-packages\object_detection\builders\model_builder.py:1102: DeprecationWarning: The 'warn' function is deprecated, use 'warning' instead
#   logging.warn(('Building experimental DeepMAC meta-arch.'
# W0814 16:12:11.640807 20408 model_builder.py:1102] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 0.45s
# I0814 16:12:11.830331 20408 test_util.py:2497] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 0.45s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 1.16s
# I0814 16:12:12.989894 20408 test_util.py:2497] time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 1.16s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.24s
# I0814 16:12:13.225423 20408 test_util.py:2497] time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.24s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.24s
# I0814 16:12:13.466802 20408 test_util.py:2497] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.24s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 1.63s
# I0814 16:12:15.097997 20408 test_util.py:2497] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 1.63s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# [ RUN      ] ModelBuilderTF2Test.test_create_experimental_model
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# I0814 16:12:15.101987 20408 test_util.py:2497] time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# [       OK ] ModelBuilderTF2Test.test_create_experimental_model
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.02s
# I0814 16:12:15.121933 20408 test_util.py:2497] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.01s
# I0814 16:12:15.135897 20408 test_util.py:2497] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.01s
# I0814 16:12:15.149858 20408 test_util.py:2497] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.08s
# I0814 16:12:15.226677 20408 test_util.py:2497] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.08s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.07s
# I0814 16:12:15.300457 20408 test_util.py:2497] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.07s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.07s
# I0814 16:12:15.376279 20408 test_util.py:2497] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.07s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.07s
# I0814 16:12:15.452074 20408 test_util.py:2497] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.07s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.07s
# I0814 16:12:15.522888 20408 test_util.py:2497] time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.07s
# [       OK ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.02s
# I0814 16:12:15.545799 20408 test_util.py:2497] time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# I0814 16:12:15.701410 20408 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet EfficientNet backbone version: efficientnet-b0
# I0814 16:12:15.701410 20408 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 64
# I0814 16:12:15.701410 20408 ssd_efficientnet_bifpn_feature_extractor.py:148] EfficientDet BiFPN num iterations: 3
# I0814 16:12:15.703378 20408 efficientnet_model.py:143] round_filter input=32 output=32
# I0814 16:12:15.724350 20408 efficientnet_model.py:143] round_filter input=32 output=32
# I0814 16:12:15.724350 20408 efficientnet_model.py:143] round_filter input=16 output=16
# I0814 16:12:15.788151 20408 efficientnet_model.py:143] round_filter input=16 output=16
# I0814 16:12:15.788151 20408 efficientnet_model.py:143] round_filter input=24 output=24
# I0814 16:12:15.952712 20408 efficientnet_model.py:143] round_filter input=24 output=24
# I0814 16:12:15.953710 20408 efficientnet_model.py:143] round_filter input=40 output=40
# I0814 16:12:16.204041 20408 efficientnet_model.py:143] round_filter input=40 output=40
# I0814 16:12:16.204041 20408 efficientnet_model.py:143] round_filter input=80 output=80
# I0814 16:12:16.426445 20408 efficientnet_model.py:143] round_filter input=80 output=80
# I0814 16:12:16.426445 20408 efficientnet_model.py:143] round_filter input=112 output=112
# I0814 16:12:16.705698 20408 efficientnet_model.py:143] round_filter input=112 output=112
# I0814 16:12:16.705698 20408 efficientnet_model.py:143] round_filter input=192 output=192
# I0814 16:12:17.026599 20408 efficientnet_model.py:143] round_filter input=192 output=192
# I0814 16:12:17.026599 20408 efficientnet_model.py:143] round_filter input=320 output=320
# I0814 16:12:17.116361 20408 efficientnet_model.py:143] round_filter input=1280 output=1280
# I0814 16:12:17.177198 20408 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.0, resolution=224, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0814 16:12:17.243022 20408 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet EfficientNet backbone version: efficientnet-b1
# I0814 16:12:17.243022 20408 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 88
# I0814 16:12:17.243022 20408 ssd_efficientnet_bifpn_feature_extractor.py:148] EfficientDet BiFPN num iterations: 4
# I0814 16:12:17.245016 20408 efficientnet_model.py:143] round_filter input=32 output=32
# I0814 16:12:17.270947 20408 efficientnet_model.py:143] round_filter input=32 output=32
# I0814 16:12:17.270947 20408 efficientnet_model.py:143] round_filter input=16 output=16
# I0814 16:12:17.399604 20408 efficientnet_model.py:143] round_filter input=16 output=16
# I0814 16:12:17.399604 20408 efficientnet_model.py:143] round_filter input=24 output=24
# I0814 16:12:17.637992 20408 efficientnet_model.py:143] round_filter input=24 output=24
# I0814 16:12:17.637992 20408 efficientnet_model.py:143] round_filter input=40 output=40
# I0814 16:12:17.850398 20408 efficientnet_model.py:143] round_filter input=40 output=40
# I0814 16:12:17.850398 20408 efficientnet_model.py:143] round_filter input=80 output=80
# I0814 16:12:18.157605 20408 efficientnet_model.py:143] round_filter input=80 output=80
# I0814 16:12:18.158573 20408 efficientnet_model.py:143] round_filter input=112 output=112
# I0814
efficientnet_model.py:143] round_filter input=16 output=32
# I0814 16:12:34.538153 20408 efficientnet_model.py:143] round_filter input=16 output=32
# I0814 16:12:34.538153 20408 efficientnet_model.py:143] round_filter input=24 output=48
# I0814 16:12:35.046459 20408 efficientnet_model.py:143] round_filter input=24 output=48
# I0814 16:12:35.047456 20408 efficientnet_model.py:143] round_filter input=40 output=80
# I0814 16:12:35.540814 20408 efficientnet_model.py:143] round_filter input=40 output=80
# I0814 16:12:35.540814 20408 efficientnet_model.py:143] round_filter input=80 output=160
# I0814 16:12:36.361670 20408 efficientnet_model.py:143] round_filter input=80 output=160
# I0814 16:12:36.361670 20408 efficientnet_model.py:143] round_filter input=112 output=224
# I0814 16:12:37.338978 20408 efficientnet_model.py:143] round_filter input=112 output=224
# I0814 16:12:37.338978 20408 efficientnet_model.py:143] round_filter input=192 output=384
# I0814 16:12:38.625174 20408 efficientnet_model.py:143] round_filter input=192 output=384
# I0814 16:12:38.625174 20408 efficientnet_model.py:143] round_filter input=320 output=640
# I0814 16:12:39.143678 20408 efficientnet_model.py:143] round_filter input=1280 output=2560
# I0814 16:12:39.204002 20408 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 23.76s
# I0814 16:12:39.310741 20408 test_util.py:2497] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 23.76s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I0814 16:12:39.333654 20408 test_util.py:2497] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I0814 16:12:39.334651 20408 test_util.py:2497] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I0814 16:12:39.335649 20408 test_util.py:2497] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I0814 16:12:39.336646 20408 test_util.py:2497] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I0814 16:12:39.338641 20408 test_util.py:2497] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I0814 16:12:39.338641 20408 test_util.py:2497] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I0814 16:12:39.339639 20408 test_util.py:2497] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 27.956s
#
# OK (skipped=1)

# %%
pip install --upgrade tf_slim
# Out:
# Requirement already satisfied: tf_slim in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (1.1.0)
# Requirement already satisfied: absl-py>=0.2.2 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tf_slim) (1.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install --upgrade protobuf==3.19.0
# Out:
# Collecting protobuf==3.19.0
#   Downloading protobuf-3.19.0-cp39-cp39-win_amd64.whl (895 kB)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.0
#     Uninstalling protobuf-3.20.0:
#       Successfully uninstalled protobuf-3.20.0
# Successfully installed protobuf-3.19.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-models-official 2.9.2 requires Cython, which is not installed.
# tf-models-official 2.9.2 requires gin-config, which is not installed.
# tf-models-official 2.9.2 requires google-api-python-client>=1.6.7, which is not installed.
# tf-models-official 2.9.2 requires kaggle>=1.3.9, which is not installed.
# tf-models-official 2.9.2 requires matplotlib, which is not installed.
# tf-models-official 2.9.2 requires oauth2client, which is not installed.
# tf-models-official 2.9.2 requires opencv-python-headless, which is not installed.
# tf-models-official 2.9.2 requires py-cpuinfo>=3.3.0, which is not installed.
# tf-models-official 2.9.2 requires pycocotools, which is not installed.
# tf-models-official 2.9.2 requires pyyaml<6.0,>=5.1, which is not installed.
# tf-models-official 2.9.2 requires sacrebleu, which is not installed.
# tf-models-official 2.9.2 requires sentencepiece, which is not installed.
# tf-models-official 2.9.2 requires seqeval, which is not installed.
# tf-models-official 2.9.2 requires tensorflow-addons, which is not installed.
# tf-models-official 2.9.2 requires tensorflow-datasets, which is not installed.
# tf-models-official 2.9.2 requires tensorflow-hub>=0.6.0, which is not installed.
# tf-models-official 2.9.2 requires tensorflow-model-optimization>=0.4.1, which is not installed.
# tf-models-official 2.9.2 requires tensorflow-text~=2.9.0, which is not installed.
# WARNING: You are using pip version 21.3.1; however, version 22.2.2 is available.
# You should consider upgrading via the 'C:\Users\Lucas2k16\Desktop\Uni\GKI\Coffeelist\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import object_detection

# %%
# !pip list
# Out:
# Package                           Version              Editable project location
# --------------------------------- -------------------- -----------------------------------------------------------------------------
# absl-py                           1.2.0
# apache-beam                       2.41.0rc1
# argon2-cffi                       21.3.0
# argon2-cffi-bindings              21.2.0
# asttokens                         2.0.5
# astunparse                        1.6.3
# attrs                             22.1.0
# avro-python3                      1.10.2
# backcall                          0.2.0
# backports.entry-points-selectable 1.1.1
# beautifulsoup4                    4.11.1
# bleach                            5.0.1
# cachetools                        5.2.0
# certifi                           2022.6.15
# cffi                              1.15.1
# charset-normalizer                2.1.0
# colorama                          0.4.5
# commonmark                        0.9.1
# contextlib2                       21.6.0
# cycler                            0.11.0
# Cython                            0.29.32
# debugpy                           1.6.2
# decorator                         5.1.1
# defusedxml                        0.7.1
# distlib                           0.3.3
# docutils                          0.19
# entrypoints                       0.4
# executing                         0.9.1
# fastjsonschema                    2.16.1
# filelock                          3.4.0
# flatbuffers                       1.12
# fonttools                         4.34.4
# gast                              0.4.0
# gin                               0.1.6
# gin-config                        0.5.0
# google-api-python-client          2.56.0
# google-auth                       2.10.0
# google-auth-oauthlib              0.4.6
# google-pasta                      0.2.0
# grpcio                            1.47.0
# h5py                              3.7.0
# idna                              3.3
# importlib-metadata                4.12.0
# ipykernel                         6.15.1
# ipython                           8.4.0
# ipython-genutils                  0.2.0
# ipywidgets                        7.7.1
# jedi                              0.18.1
# Jinja2                            3.1.2
# jsonschema                        4.9.1
# jupyter                           1.0.0
# jupyter-client                    7.3.4
# jupyter-console                   6.4.4
# jupyter-core                      4.11.1
# jupyterlab-pygments               0.2.2
# jupyterlab-widgets                1.1.1
# kaggle                            1.5.12
# keras                             2.9.0
# keras-nightly                     2.11.0.dev2022081107
# Keras-Preprocessing               1.1.2
# keyring                           23.8.2
# kiwisolver                        1.4.4
# libclang                          14.0.6
# lvis                              0.5.3
# lxml                              4.9.1
# Markdown                          3.4.1
# MarkupSafe                        2.1.1
# matplotlib                        3.5.2
# matplotlib-inline                 0.1.3
# mistune                           0.8.4
# nbclient                          0.6.6
# nbconvert                         6.5.0
# nbformat                          5.4.0
# nest-asyncio                      1.5.5
# notebook                          6.4.12
# numpy                             1.23.1
# oauth2client                      4.1.3
# oauthlib                          3.2.0
# object-detection                  0.1
# opencv-contrib-python             4.5.5.62
# opencv-python                     4.6.0.66
# opencv-python-headless            4.6.0.66
# opt-einsum                        3.3.0
# orjson                            3.7.11
# packaging                         21.3
# pandas                            1.4.3
# pandocfilters                     1.5.0
# parso                             0.8.3
# pickleshare                       0.7.5
# Pillow                            9.2.0
# pip                               22.2.2
# pipenv                            2021.11.23
# pkginfo                           1.8.3
# platformdirs                      2.4.0
# prometheus-client                 0.14.1
# prompt-toolkit                    3.0.30
# proto-plus                        1.22.0
# protobuf                          3.19.4
# psutil                            5.9.1
# pure-eval                         0.2.2
# py-cpuinfo                        8.0.0
# pyarrow                           7.0.0
# pyasn1                            0.4.8
# pyasn1-modules                    0.2.8
# pycocotools                       2.0.4
# pycparser                         2.21
# pydot                             1.4.2
# Pygments                          2.12.0
# pymongo                           3.12.3
# pyparsing                         3.0.9
# pypiwin32                         223
# pyrsistent                        0.18.1
# pytesseract                       0.3.9
# python-dateutil                   2.8.2
# pytz                              2022.1
# pywin32                           304
# pywin32-ctypes                    0.2.0
# pywinpty                          2.0.7
# PyYAML                            6.0
# pyzmq                             23.2.0
# qtconsole                         5.3.1
# QtPy                              2.1.0
# readme-renderer                   36.0
# requests                          2.28.1
# requests-oauthlib                 1.3.1
# requests-toolbelt                 0.9.1
# rfc3986                           2.0.0
# rich                              12.5.1
# rsa                               4.9
# sacrebleu                         2.2.0
# scipy                             1.9.0
# Send2Trash                        1.8.0
# sentencepiece                     0.1.97
# seqeval                           1.2.2
# setuptools                        60.2.0
# six                               1.16.0
# slim                              0.1                  c:\users\lucas2k16\desktop\uni\gki\coffeelist\tensorflow\models\research\slim
# soupsieve                         2.3.2.post1
# stack-data                        0.3.0
# tensorboard                       2.9.1
# tensorboard-data-server           0.6.1
# tensorboard-plugin-wit            1.8.1
# tensorflow                        2.9.0
# tensorflow-addons                 0.17.1
# tensorflow-datasets               4.6.0
# tensorflow-estimator              2.9.0
# tensorflow-gpu                    2.9.1
# tensorflow-hub                    0.12.0
# tensorflow-io                     0.26.0
# tensorflow-io-gcs-filesystem      0.26.0
# tensorflow-model-optimization     0.7.3
# tensorflow-object-detection-api   0.1.1
# tensorflow-text                   2.9.0
# termcolor                         1.1.0
# terminado                         0.15.0
# tf-models-official                2.9.2
# tf-nightly                        2.11.0.dev20220812
# tf-slim                           1.1.0
# tinycss2                          1.1.1
# tornado                           6.2
# traitlets                         5.3.0
# twine                             4.0.1
# typeguard                         2.13.3
# typing_extensions                 4.3.0
# urllib3                           1.26.11
# virtualenv                        20.10.0
# virtualenv-clone                  0.5.7
# wcwidth                           0.2.5
# webencodings                      0.5.1
# Werkzeug                          2.2.1
# wget                              3.2
# wheel                             0.37.1
# widgetsnbextension                3.6.1
# wrapt                             1.14.1
# zipp                              3.8.1

# %%
if os.name =='posix':
    # !wget {PRETRAINED_MODEL_URL}
    # !mv {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
if os.name == 'nt':
    wget.download(PRETRAINED_MODEL_URL)
    # !move {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
# Out:
#  20% [..............                                                          ]  4194304 / 20518283
#  52% [.....................................                                   ] 10723328 / 20518283
#  84% [............................................................            ] 17367040 / 20518283
# 100% [........................................................................] 20518283 / 20518283
#         1 file(s) moved.
# x ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/
# x ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/checkpoint/
# x ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# x ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/checkpoint/checkpoint
# x ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/checkpoint/ckpt-0.index
# x ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/pipeline.config
# x ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/
# x ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/saved_model.pb
# x ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/variables/
# x ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# x ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/variables/variables.index

# %%
labels = [{'name':'Block', 'id':1}, {'name':'Single', 'id':2}]

with open(files['LABELMAP'], 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %%
if not os.path.exists(files['TF_RECORD_SCRIPT']):
    # !git clone https://github.com/nicknochnack/GenerateTFRecord {paths['SCRIPTS_PATH']}

# %%
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'train')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'train.record')} 
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'test')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'test.record')}
# Out:
# Successfully created the TFRecord file: Tensorflow\workspace\annotations\train.record
# 2022-08-13 21:06:03.927111: E tensorflow/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (100)
# Successfully created the TFRecord file: Tensorflow\workspace\annotations\test.record
# 2022-08-13 21:06:07.835304: E tensorflow/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (100)

# %%
if os.name =='posix':
    # !cp {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
if os.name == 'nt':
    # !copy {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
# Out:
#         1 file(s) copied.

# %%
pip uninstall tensorflow-object-detection-api
# Out:
# Collecting tensorflow-object-detection-api
#   Downloading tensorflow_object_detection_api-0.1.1.tar.gz (577 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: Pillow>=1.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-object-detection-api) (9.2.0)
# Requirement already satisfied: Matplotlib>=2.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-object-detection-api) (3.5.2)
# Collecting Cython>=0.28.1
#   Downloading Cython-0.29.32-py2.py3-none-any.whl (986 kB)
# Requirement already satisfied: Protobuf in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-object-detection-api) (3.19.0)
# Collecting lxml
#   Downloading lxml-4.9.1-cp39-cp39-win_amd64.whl (3.6 MB)
# Requirement already satisfied: jupyter in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-object-detection-api) (1.0.0)
# Requirement already satisfied: tensorflow in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-object-detection-api) (2.9.1)
# Collecting contextlib2
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: wheel in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-object-detection-api) (0.37.1)
# Collecting twine
#   Downloading twine-4.0.1-py3-none-any.whl (36 kB)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (3.0.9)
# Requirement already satisfied: numpy>=1.17 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (1.23.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (4.34.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (21.3)
# Requirement already satisfied: ipywidgets in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from jupyter->tensorflow-object-detection-api) (7.7.1)
# Requirement already satisfied: nbconvert in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from jupyter->tensorflow-object-detection-api) (6.5.0)
# Requirement already satisfied: ipykernel in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from jupyter->tensorflow-object-detection-api) (6.15.1)
# Requirement already satisfied: jupyter-console in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from jupyter->tensorflow-object-detection-api) (6.4.4)
# Requirement already satisfied: notebook in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from jupyter->tensorflow-object-detection-api) (6.4.12)
# Requirement already satisfied: qtconsole in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from jupyter->tensorflow-object-detection-api) (5.3.1)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow->tensorflow-object-detection-api) (2.9.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow->tensorflow-object-detection-api) (1.47.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow->tensorflow-object-detection-api) (0.26.0)
# Requirement already satisfied: setuptools in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow->tensorflow-object-detection-api) (60.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow->tensorflow-object-detection-api) (1.14.1)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow->tensorflow-object-detection-api) (2.9.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow->tensorflow-object-detection-api) (14.0.6)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow->tensorflow-object-detection-api) (3.7.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow->tensorflow-object-detection-api) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow->tensorflow-object-detection-api) (4.3.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow->tensorflow-object-detection-api) (0.2.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow->tensorflow-object-detection-api) (0.4.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow->tensorflow-object-detection-api) (1.12)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow->tensorflow-object-detection-api) (1.6.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow->tensorflow-object-detection-api) (1.16.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow->tensorflow-object-detection-api) (1.1.2)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow->tensorflow-object-detection-api) (1.2.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow->tensorflow-object-detection-api) (2.9.1)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow->tensorflow-object-detection-api) (1.1.0)
# Collecting rfc3986>=1.4.0
#   Downloading rfc3986-2.0.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from twine->tensorflow-object-detection-api) (1.26.11)
# Collecting readme-renderer>=35.0
#   Downloading readme_renderer-36.0-py3-none-any.whl (14 kB)
# Collecting keyring>=15.1
#   Downloading keyring-23.8.2-py3-none-any.whl (34 kB)
# Collecting rich>=12.0.0
#   Downloading rich-12.5.1-py3-none-any.whl (235 kB)
# Requirement already satisfied: importlib-metadata>=3.6 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from twine->tensorflow-object-detection-api) (4.12.0)
# Collecting requests-toolbelt!=0.9.0,>=0.8.0
#   Downloading requests_toolbelt-0.9.1-py2.py3-none-any.whl (54 kB)
# Collecting pkginfo>=1.8.1
#   Downloading pkginfo-1.8.3-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: requests>=2.20 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from twine->tensorflow-object-detection-api) (2.28.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from importlib-metadata>=3.6->twine->tensorflow-object-detection-api) (3.8.1)
# Collecting pywin32-ctypes!=0.1.0,!=0.1.1
#   Downloading pywin32_ctypes-0.2.0-py2.py3-none-any.whl (28 kB)
# Requirement already satisfied: Pygments>=2.5.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from readme-renderer>=35.0->twine->tensorflow-object-detection-api) (2.12.0)
# Requirement already satisfied: bleach>=2.1.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from readme-renderer>=35.0->twine->tensorflow-object-detection-api) (5.0.1)
# Collecting docutils>=0.13.1
#   Downloading docutils-0.19-py3-none-any.whl (570 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from requests>=2.20->twine->tensorflow-object-detection-api) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from requests>=2.20->twine->tensorflow-object-detection-api) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from requests>=2.20->twine->tensorflow-object-detection-api) (3.3)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow->tensorflow-object-detection-api) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow->tensorflow-object-detection-api) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow->tensorflow-object-detection-api) (2.2.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow->tensorflow-object-detection-api) (2.10.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow->tensorflow-object-detection-api) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow->tensorflow-object-detection-api) (3.4.1)
# Requirement already satisfied: debugpy>=1.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (1.6.2)
# Requirement already satisfied: pyzmq>=17 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (23.2.0)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (8.4.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (0.1.3)
# Requirement already satisfied: nest-asyncio in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (1.5.5)
# Requirement already satisfied: traitlets>=5.1.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (5.3.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (6.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (7.3.4)
# Requirement already satisfied: psutil in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (5.9.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from ipywidgets->jupyter->tensorflow-object-detection-api) (3.6.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from ipywidgets->jupyter->tensorflow-object-detection-api) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from ipywidgets->jupyter->tensorflow-object-detection-api) (1.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from jupyter-console->jupyter->tensorflow-object-detection-api) (3.0.30)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (1.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (2.1.1)
# Requirement already satisfied: tinycss2 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (1.1.1)
# Requirement already satisfied: jupyter-core>=4.7 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (4.11.1)
# Requirement already satisfied: defusedxml in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (0.2.2)
# Requirement already satisfied: nbformat>=5.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (5.4.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (4.11.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (0.6.6)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (0.4)
# Requirement already satisfied: argon2-cffi in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from notebook->jupyter->tensorflow-object-detection-api) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from notebook->jupyter->tensorflow-object-detection-api) (1.8.0)
# Requirement already satisfied: prometheus-client in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from notebook->jupyter->tensorflow-object-detection-api) (0.14.1)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from notebook->jupyter->tensorflow-object-detection-api) (0.15.0)
# Requirement already satisfied: qtpy>=2.0.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from qtconsole->jupyter->tensorflow-object-detection-api) (2.1.0)
# Requirement already satisfied: webencodings in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from bleach>=2.1.0->readme-renderer>=35.0->twine->tensorflow-object-detection-api) (0.5.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow->tensorflow-object-detection-api) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow->tensorflow-object-detection-api) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow->tensorflow-object-detection-api) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow->tensorflow-object-detection-api) (1.3.1)
# Requirement already satisfied: colorama in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (0.4.5)
# Requirement already satisfied: pickleshare in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (0.7.5)
# Requirement already satisfied: decorator in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (5.1.1)
# Requirement already satisfied: stack-data in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (0.3.0)
# Requirement already satisfied: backcall in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (0.18.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from jupyter-core>=4.7->nbconvert->jupyter->tensorflow-object-detection-api) (304)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from nbformat>=5.1->nbconvert->jupyter->tensorflow-object-detection-api) (4.9.1)
# Requirement already satisfied: fastjsonschema in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from nbformat>=5.1->nbconvert->jupyter->tensorflow-object-detection-api) (2.16.1)
# Requirement already satisfied: wcwidth in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter->tensorflow-object-detection-api) (0.2.5)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from terminado>=0.8.3->notebook->jupyter->tensorflow-object-detection-api) (2.0.7)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from argon2-cffi->notebook->jupyter->tensorflow-object-detection-api) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->tensorflow-object-detection-api) (2.3.2.post1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->tensorflow-object-detection-api) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->tensorflow-object-detection-api) (0.18.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow->tensorflow-object-detection-api) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow->tensorflow-object-detection-api) (3.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->tensorflow-object-detection-api) (1.15.1)
# Requirement already satisfied: asttokens in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (2.0.5)
# Requirement already satisfied: executing in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (0.9.1)
# Requirement already satisfied: pure-eval in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (0.2.2)
# Requirement already satisfied: pycparser in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->tensorflow-object-detection-api) (2.21)
# Building wheels for collected packages: tensorflow-object-detection-api
#   Building wheel for tensorflow-object-detection-api (setup.py): started
#   Building wheel for tensorflow-object-detection-api (setup.py): finished with status 'done'
#   Created wheel for tensorflow-object-detection-api: filename=tensorflow_object_detection_api-0.1.1-py3-none-any.whl size=844512 sha256=2071dc8fb003fb143ffb597415d6c5c57bd2dc1f481cc0fa3a1ef5c19f8b55f9
#   Stored in directory: c:\users\lucas2k16\appdata\local\pip\cache\wheels\38\6f\73\3c0c70f9a8219c31c96c495b686af1416154b60707fd96a4cd
# Successfully built tensorflow-object-detection-api
# Installing collected packages: pywin32-ctypes, docutils, commonmark, rich, rfc3986, requests-toolbelt, readme-renderer, pkginfo, keyring, twine, lxml, Cython, contextlib2, tensorflow-object-detection-api
# Successfully installed Cython-0.29.32 commonmark-0.9.1 contextlib2-21.6.0 docutils-0.19 keyring-23.8.2 lxml-4.9.1 pkginfo-1.8.3 pywin32-ctypes-0.2.0 readme-renderer-36.0 requests-toolbelt-0.9.1 rfc3986-2.0.0 rich-12.5.1 tensorflow-object-detection-api-0.1.1 twine-4.0.1
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# object-detection 0.1 requires apache-beam, which is not installed.
# object-detection 0.1 requires avro-python3, which is not installed.
# object-detection 0.1 requires pycocotools, which is not installed.
# tf-models-official 2.9.2 requires gin-config, which is not installed.
# tf-models-official 2.9.2 requires google-api-python-client>=1.6.7, which is not installed.
# tf-models-official 2.9.2 requires kaggle>=1.3.9, which is not installed.
# tf-models-official 2.9.2 requires oauth2client, which is not installed.
# tf-models-official 2.9.2 requires opencv-python-headless, which is not installed.
# tf-models-official 2.9.2 requires py-cpuinfo>=3.3.0, which is not installed.
# tf-models-official 2.9.2 requires pycocotools, which is not installed.
# tf-models-official 2.9.2 requires sacrebleu, which is not installed.
# tf-models-official 2.9.2 requires sentencepiece, which is not installed.
# tf-models-official 2.9.2 requires seqeval, which is not installed.
# tf-models-official 2.9.2 requires tensorflow-addons, which is not installed.
# tf-models-official 2.9.2 requires tensorflow-datasets, which is not installed.
# tf-models-official 2.9.2 requires tensorflow-hub>=0.6.0, which is not installed.
# tf-models-official 2.9.2 requires tensorflow-model-optimization>=0.4.1, which is not installed.
# tf-models-official 2.9.2 requires tensorflow-text~=2.9.0, which is not installed.
# object-detection 0.1 requires pyparsing==2.4.7, but you have pyparsing 3.0.9 which is incompatible.
# tf-models-official 2.9.2 requires pyyaml<6.0,>=5.1, but you have pyyaml 6.0 which is incompatible.
# WARNING: You are using pip version 21.3.1; however, version 22.2.2 is available.
# You should consider upgrading via the 'C:\Users\Lucas2k16\Desktop\Uni\GKI\Coffeelist\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
config = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])

# %%
config
# Out:
# {'model': ssd {
#    num_classes: 2
#    image_resizer {
#      fixed_shape_resizer {
#        height: 640
#        width: 640
#      }
#    }
#    feature_extractor {
#      type: "ssd_mobilenet_v2_fpn_keras"
#      depth_multiplier: 1.0
#      min_depth: 16
#      conv_hyperparams {
#        regularizer {
#          l2_regularizer {
#            weight: 3.9999998989515007e-05
#          }
#        }
#        initializer {
#          random_normal_initializer {
#            mean: 0.0
#            stddev: 0.009999999776482582
#          }
#        }
#        activation: RELU_6
#        batch_norm {
#          decay: 0.996999979019165
#          scale: true
#          epsilon: 0.0010000000474974513
#        }
#      }
#      use_depthwise: true
#      override_base_feature_extractor_hyperparams: true
#      fpn {
#        min_level: 3
#        max_level: 7
#        additional_layer_depth: 128
#      }
#    }
#    box_coder {
#      faster_rcnn_box_coder {
#        y_scale: 10.0
#        x_scale: 10.0
#        height_scale: 5.0
#        width_scale: 5.0
#      }
#    }
#    matcher {
#      argmax_matcher {
#        matched_threshold: 0.5
#        unmatched_threshold: 0.5
#        ignore_thresholds: false
#        negatives_lower_than_unmatched: true
#        force_match_for_each_row: true
#        use_matmul_gather: true
#      }
#    }
#    similarity_calculator {
#      iou_similarity {
#      }
#    }
#    box_predictor {
#      weight_shared_convolutional_box_predictor {
#        conv_hyperparams {
#          regularizer {
#            l2_regularizer {
#              weight: 3.9999998989515007e-05
#            }
#          }
#          initializer {
#            random_normal_initializer {
#              mean: 0.0
#              stddev: 0.009999999776482582
#            }
#          }
#          activation: RELU_6
#          batch_norm {
#            decay: 0.996999979019165
#            scale: true
#            epsilon: 0.0010000000474974513
#          }
#        }
#        depth: 128
#        num_layers_before_predictor: 4
#        kernel_size: 3
#        class_prediction_bias_init: -4.599999904632568
#        share_prediction_tower: true
#        use_depthwise: true
#      }
#    }
#    anchor_generator {
#      multiscale_anchor_generator {
#        min_level: 3
#        max_level: 7
#        anchor_scale: 4.0
#        aspect_ratios: 1.0
#        aspect_ratios: 2.0
#        aspect_ratios: 0.5
#        scales_per_octave: 2
#      }
#    }
#    post_processing {
#      batch_non_max_suppression {
#        score_threshold: 9.99999993922529e-09
#        iou_threshold: 0.6000000238418579
#        max_detections_per_class: 100
#        max_total_detections: 100
#        use_static_shapes: false
#      }
#      score_converter: SIGMOID
#    }
#    normalize_loss_by_num_matches: true
#    loss {
#      localization_loss {
#        weighted_smooth_l1 {
#        }
#      }
#      classification_loss {
#        weighted_sigmoid_focal {
#          gamma: 2.0
#          alpha: 0.25
#        }
#      }
#      classification_weight: 1.0
#      localization_weight: 1.0
#    }
#    encode_background_as_zeros: true
#    normalize_loc_loss_by_codesize: true
#    inplace_batchnorm_update: true
#    freeze_batchnorm: false
#  },
#  'train_config': batch_size: 4
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_crop_image {
#      min_object_covered: 0.0
#      min_aspect_ratio: 0.75
#      max_aspect_ratio: 3.0
#      min_area: 0.75
#      max_area: 1.0
#      overlap_thresh: 0.0
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.07999999821186066
#          total_steps: 50000
#          warmup_learning_rate: 0.026666000485420227
#          warmup_steps: 1000
#        }
#      }
#      momentum_optimizer_value: 0.8999999761581421
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "Tensorflow\\workspace\\pre-trained-models\\ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8\\checkpoint\\ckpt-0"
#  num_steps: 50000
#  startup_delay_steps: 0.0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "detection"
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': label_map_path: "Tensorflow\\workspace\\annotations\\label_map.pbtxt"
#  tf_record_input_reader {
#    input_path: "Tensorflow\\workspace\\annotations\\train.record"
#  },
#  'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false,
#  'eval_input_configs': [label_map_path: "Tensorflow\\workspace\\annotations\\label_map.pbtxt"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "Tensorflow\\workspace\\annotations\\test.record"
#  }
#  ],
#  'eval_input_config': label_map_path: "Tensorflow\\workspace\\annotations\\label_map.pbtxt"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "Tensorflow\\workspace\\annotations\\test.record"
#  }}

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.ssd.num_classes = len(labels)
pipeline_config.train_config.batch_size = 4
pipeline_config.train_config.fine_tune_checkpoint = os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'checkpoint', 'ckpt-0')
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= files['LABELMAP']
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'train.record')]
pipeline_config.eval_input_reader[0].label_map_path = files['LABELMAP']
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'test.record')]

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %%
# TRAINING MODEL

# %%
TRAINING_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'model_main_tf2.py')

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --num_train_steps=2000".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\model_main_tf2.py --model_dir=Tensorflow\workspace\models\my_ssd_mobnet --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet\pipeline.config --num_train_steps=2000

# %%
# !pip install tensorflow-gpu
# Out:
# Collecting tensorflow-gpu
#   Using cached tensorflow_gpu-2.9.1-cp39-cp39-win_amd64.whl (444.0 MB)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (1.1.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (1.14.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (14.0.6)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (2.9.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (1.12)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (1.47.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (3.7.0)
# Requirement already satisfied: packaging in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (21.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (1.16.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: setuptools in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (60.2.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (2.9.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (2.9.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (3.19.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (0.26.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (0.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (4.3.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (1.23.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (1.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from astunparse>=1.6.0->tensorflow-gpu) (0.37.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu) (2.2.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu) (2.10.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu) (2.28.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from packaging->tensorflow-gpu) (3.0.9)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow-gpu) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow-gpu) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow-gpu) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow-gpu) (4.12.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow-gpu) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow-gpu) (2.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow-gpu) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow-gpu) (2022.6.15)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.10,>=2.9->tensorflow-gpu) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow-gpu) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow-gpu) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow-gpu) (3.2.0)
# Installing collected packages: tensorflow-gpu
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\Lucas2k16\\Desktop\\Uni\\GKI\\Coffeelist\\venv\\Lib\\site-packages\\tensorflow\\compiler\\tf2tensorrt\\_pywrap_py_utils.pyd'
# Check the permissions.

# %%
# !pip install tensorflow-gpu --user
# Out:
# Collecting tensorflow-gpu
#   Using cached tensorflow_gpu-2.9.1-cp39-cp39-win_amd64.whl (444.0 MB)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (2.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (1.47.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (1.14.1)
# Requirement already satisfied: setuptools in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (60.2.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (1.12)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (1.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (3.7.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (0.26.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (0.4.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (2.9.1)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (14.0.6)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (2.9.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (3.19.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (4.3.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: packaging in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (21.3)
# Requirement already satisfied: numpy>=1.20 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorflow-gpu) (1.23.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from astunparse>=1.6.0->tensorflow-gpu) (0.37.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu) (2.2.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu) (2.10.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu) (2.28.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu) (3.4.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from packaging->tensorflow-gpu) (3.0.9)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow-gpu) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow-gpu) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow-gpu) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow-gpu) (4.12.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow-gpu) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow-gpu) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow-gpu) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow-gpu) (3.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.10,>=2.9->tensorflow-gpu) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow-gpu) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow-gpu) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow-gpu) (3.2.0)
# Installing collected packages: tensorflow-gpu
# Successfully installed tensorflow-gpu-2.9.1
#   WARNING: The scripts estimator_ckpt_converter.exe, import_pb_to_tensorboard.exe, saved_model_cli.exe, tensorboard.exe, tf_upgrade_v2.exe, tflite_convert.exe, toco.exe and toco_from_protos.exe are installed in 'C:\Users\Lucas2k16\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
pip list
# Out:
# Package                           Version     Editable project location
# --------------------------------- ----------- -----------------------------------------------------------------------------
# absl-py                           1.2.0
# apache-beam                       2.41.0rc1
# argon2-cffi                       21.3.0
# argon2-cffi-bindings              21.2.0
# asttokens                         2.0.5
# astunparse                        1.6.3
# attrs                             22.1.0
# avro-python3                      1.10.2
# backcall                          0.2.0
# backports.entry-points-selectable 1.1.1
# beautifulsoup4                    4.11.1
# bleach                            5.0.1
# cachetools                        5.2.0
# certifi                           2022.6.15
# cffi                              1.15.1
# charset-normalizer                2.1.0
# colorama                          0.4.5
# commonmark                        0.9.1
# contextlib2                       21.6.0
# cycler                            0.11.0
# Cython                            0.29.32
# debugpy                           1.6.2
# decorator                         5.1.1
# defusedxml                        0.7.1
# distlib                           0.3.3
# docutils                          0.19
# entrypoints                       0.4
# executing                         0.9.1
# fastjsonschema                    2.16.1
# filelock                          3.4.0
# flatbuffers                       1.12
# fonttools                         4.34.4
# gast                              0.4.0
# gin                               0.1.6
# gin-config                        0.5.0
# google-auth                       2.10.0
# google-auth-oauthlib              0.4.6
# google-pasta                      0.2.0
# grpcio                            1.47.0
# h5py                              3.7.0
# idna                              3.3
# importlib-metadata                4.12.0
# ipykernel                         6.15.1
# ipython                           8.4.0
# ipython-genutils                  0.2.0
# ipywidgets                        7.7.1
# jedi                              0.18.1
# Jinja2                            3.1.2
# jsonschema                        4.9.1
# jupyter                           1.0.0
# jupyter-client                    7.3.4
# jupyter-console                   6.4.4
# jupyter-core                      4.11.1
# jupyterlab-pygments               0.2.2
# jupyterlab-widgets                1.1.1
# keras                             2.9.0
# Keras-Preprocessing               1.1.2
# keyring                           23.8.2
# kiwisolver                        1.4.4
# libclang                          14.0.6
# lvis                              0.5.3
# lxml                              4.9.1
# Markdown                          3.4.1
# MarkupSafe                        2.1.1
# matplotlib                        3.5.2
# matplotlib-inline                 0.1.3
# mistune                           0.8.4
# nbclient                          0.6.6
# nbconvert                         6.5.0
# nbformat                          5.4.0
# nest-asyncio                      1.5.5
# notebook                          6.4.12
# numpy                             1.23.1
# oauthlib                          3.2.0
# object-detection                  0.1
# opencv-contrib-python             4.5.5.62
# opencv-python                     4.6.0.66
# opt-einsum                        3.3.0
# packaging                         21.3
# pandas                            1.4.3
# pandocfilters                     1.5.0
# parso                             0.8.3
# pickleshare                       0.7.5
# Pillow                            9.2.0
# pip                               22.2.2
# pipenv                            2021.11.23
# pkginfo                           1.8.3
# platformdirs                      2.4.0
# prometheus-client                 0.14.1
# prompt-toolkit                    3.0.30
# protobuf                          3.19.0
# psutil                            5.9.1
# pure-eval                         0.2.2
# pyasn1                            0.4.8
# pyasn1-modules                    0.2.8
# pycocotools                       2.0.4
# pycparser                         2.21
# Pygments                          2.12.0
# pyparsing                         3.0.9
# pypiwin32                         223
# pyrsistent                        0.18.1
# pytesseract                       0.3.9
# python-dateutil                   2.8.2
# pytz                              2022.1
# pywin32                           304
# pywin32-ctypes                    0.2.0
# pywinpty                          2.0.7
# PyYAML                            6.0
# pyzmq                             23.2.0
# qtconsole                         5.3.1
# QtPy                              2.1.0
# readme-renderer                   36.0
# requests                          2.28.1
# requests-oauthlib                 1.3.1
# requests-toolbelt                 0.9.1
# rfc3986                           2.0.0
# rich                              12.5.1
# rsa                               4.9
# scipy                             1.9.0
# Send2Trash                        1.8.0
# setuptools                        60.2.0
# six                               1.16.0
# slim                              0.1         c:\users\lucas2k16\desktop\uni\gki\coffeelist\tensorflow\models\research\slim
# soupsieve                         2.3.2.post1
# stack-data                        0.3.0
# tensorboard                       2.9.1
# tensorboard-data-server           0.6.1
# tensorboard-plugin-wit            1.8.1
# tensorflow-addons                 0.17.1
# tensorflow-estimator              2.9.0
# tensorflow-gpu                    2.9.1
# tensorflow-io                     0.26.0
# tensorflow-io-gcs-filesystem      0.26.0
# tensorflow-object-detection-api   0.1.1
# tensorflow-text                   2.9.0
# termcolor                         1.1.0
# terminado                         0.15.0
# tf-models-official                2.9.2
# tf-slim                           1.1.0
# tinycss2                          1.1.1
# tornado                           6.2
# traitlets                         5.3.0
# twine                             4.0.1
# typeguard                         2.13.3
# typing_extensions                 4.3.0
# urllib3                           1.26.11
# virtualenv                        20.10.0
# virtualenv-clone                  0.5.7
# wcwidth                           0.2.5
# webencodings                      0.5.1
# Werkzeug                          2.2.1
# wget                              3.2
# wheel                             0.37.1
# widgetsnbextension                3.6.1
# wrapt                             1.14.1
# zipp                              3.8.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow.python.client import device_lib 
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 15899818044389065555
# xla_global_id: -1
# ]

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
pip install tf-nightly-gpu --user
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 3471372779831022600
# xla_global_id: -1
# ]

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --checkpoint_dir={}".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\model_main_tf2.py --model_dir=Tensorflow\workspace\models\my_ssd_mobnet --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet\pipeline.config --checkpoint_dir=Tensorflow\workspace\models\my_ssd_mobnet

# %%
import os
import tensorflow as tf
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder
from object_detection.utils import config_util

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], 'ckpt-7')).expect_partial()

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
from object_detection.utils import label_map_util

# %%
category_index = label_map_util.create_category_index_from_labelmap(files['LABELMAP'])

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'train', '5ea21e8f-CL_DATA_010822_2.jpeg')

# %%
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=5,
            min_score_thresh=.8,
            agnostic_mode=False)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()

# %%
pip install utils
# Out:
# Requirement already satisfied: utils in c:\users\lucas2k16\desktop\uni\gki\coffeelist\venv\lib\site-packages (1.0.1)
# Note: you may need to restart the kernel to use updated packages.
